# %%
import numpy as np

# %%
v = np.array([1,2])
print(v)
# Out:
# [1 2]

# %%
v_manual =[]
for elem in [1,2]:
    v_manual.append(elem)
print(v_manual)
# Out:
# [1, 2]

# %%
a = np.array([1,2])
b = np.array([3,4])

# %%
result = np.add(a,b)
print(result)
# Out:
# [4 6]

# %%
result_manual = []
for i in range(len(a)):
    result_manual.append(a[i] + b[i])
print(result_manual)
# Out:
# [np.int64(4), np.int64(6)]

# %%
result = np.subtract(a,b)
print(result)
# Out:
# [-2 -2]

# %%
result_manual = []
for i in range(len(a)):
    result_manual.append(a[i] - b[i])
print(result_manual)
# Out:
# [np.int64(-2), np.int64(-2)]

# %%
result = np.multiply(a, 2)
print(result)
# Out:
# [2 4]

# %%
result_manual = []
for i in range(len(a)):
    result_manual.append(a[i] * 2)
print(result_manual)
# Out:
# [np.int64(2), np.int64(4)]

# %%
result = np.multiply(b, 0.5)
print(result)
# Out:
# [1.5 2. ]

# %%
result_manual = []
for i in range(len(b)):
    result_manual.append(b[i] * 0.5)
print(result_manual)
# Out:
# [np.float64(1.5), np.float64(2.0)]

# %%
result = np.multiply(b, -3)
print(result)
# Out:
# [ -9 -12]

# %%
result_manual = []
for i in range(len(b)):
    result_manual.append(b[i] * -3)
print(result_manual)
# Out:
# [np.int64(-9), np.int64(-12)]

# %%
result = np.linalg.norm(a)
print(result)
# Out:
# 2.23606797749979

# %%
cem = 0
for i in range(len(a)):
    cem = cem + a[i]**2
result_manual = cem**0.5
print(result_manual)
# Out:
# 2.23606797749979

# %%
result = np.dot(a,b)
print(result)
# Out:
# 11

# %%
cem = 0
for i in range(len(a)):
    cem = cem + a[i] * b[i]
print(cem)
# Out:
# 11

# %%
cos_theta = np.dot(a,b) / (np.linalg.norm(a) * np.linalg.norm(b))
angle = np.arccos(cos_theta)
print(angle)
# Out:
# 0.17985349979247847

# %%
print(np.degrees(angle))
# Out:
# 10.304846468766044

# %%
result = a / np.linalg.norm(a)
print(result)
# Out:
# [0.4472136  0.89442719]

# %%
print(np.linalg.norm(result))
# Out:
# 0.9999999999999999

# %%
result = 2 * a + 3 * b
print(result)
# Out:
# [11 16]

# %%
a3 = np.array([1,2,3])
b3 = np.array([4,5,6])

# %%
result = np.add(a3,b3)
print(result)
# Out:
# [5 7 9]

# %%
result = np.subtract(a3,b3)
print(result)
# Out:
# [-3 -3 -3]

# %%
result = np.linalg.norm(a3)
print(result)
# Out:
# 3.7416573867739413
